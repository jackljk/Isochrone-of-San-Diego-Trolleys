# %%
import pandas as pd

# %%
data = pd.read_csv('Appendix D_ OutreachCallsSourceData2.xlsx - OutreachCallsSourceData2.csv')
# Out:
# c:\Users\16195\anaconda3\envs\dsc80\lib\site-packages\IPython\core\interactiveshell.py:3378: DtypeWarning: Columns (1,2,4,34,35,36,37,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#    count                                        ProjectName  \
# 0   6366  9951 Dolores St Spring Valley; CA 91977 - Apar...
# 1  12411                                                NaN
# 2  12389                                                NaN
# 3  12338                                                NaN
# 4  10920                                                NaN
#
#    OfficePhoneNumber   email  \
# 0     (209) 764-0077     NaN
# 1     (442) 245-5178     NaN
# 2     (442) 245-5429     NaN
# 3     (442) 245-5429     NaN
# 4     (442) 248-8207     NaN
#
#                                              website   parcelnumb  \
# 0  https://www.apartments.com/9951-dolores-st-spr...   5012470100
# 1                                                NaN   1690111200
# 2                                                NaN   1614901300
# 3                                                NaN   1614901200
# 4                                                NaN   2291603000
#
# ...

# %%
data.dropna(subset=[' address'], inplace=True)

# %%
pd.set_option('display.max_columns', None)
data[data[' address'].str.contains('NOBEL')]
# Out:
#        count  ProjectName  OfficePhoneNumber   email  website   parcelnumb  \
# 1599   12349          NaN     (858) 452-3622     NaN      NaN   3451903500
# 1649   11428          NaN     (858) 558-1678     NaN      NaN   3487500100
# 1674   11117          NaN     (858) 638-0105     NaN      NaN   3487500200
# 28061  12399          NaN                NaN     NaN      NaN   3451203500
# 31030  11499          NaN                NaN     NaN      NaN   3487500300
#
#                             owner        address      scity        szip  \
# 1599              NOBEL COURT L P  3707 NOBEL DR  SAN DIEGO  92122-4589
# 1649   WHISPERING PINES NOBEL LLC  4085 NOBEL DR  SAN DIEGO  92122-5867
# 1674           LA JOLLA NOBEL L P  4149 NOBEL DR  SAN DIEGO  92122-1105
# 28061  LA JOLLA INTERNATIONAL LTD  3899 NOBEL DR  SAN DIEGO  92122-5757
# 31030          LA JOLLA NOBEL L P  4249 NOBEL DR  SAN DIEGO  92122-1113
#
#         usecode   ll_bldg_footprint_sqft   ll_bldg_count      parval  owner2  \
# ...

# %%
data[data[' address'] == '4249 NOBEL DR']
# Out:
#        count  ProjectName  OfficePhoneNumber   email  website   parcelnumb  \
# 31030  11499          NaN                NaN     NaN      NaN   3487500300
#
#                     owner        address      scity        szip   usecode  \
# 31030  LA JOLLA NOBEL L P  4249 NOBEL DR  SAN DIEGO  92122-1113    1200.0
#
#         ll_bldg_footprint_sqft   ll_bldg_count     parval  owner2  \
# 31030                  31209.0             3.0  6604999.0     NaN
#
#                                       mailadd                    careof  \
# 31030  9948 HIBERT ST #210 SAN DIEGO CA 92131  WILLMARK COMMUNITIES INC
#
#        ownerocc   unitqty   asr_landuse   asr_zone   year_effec   total_lvg_   \
# 31030       NaN      64.0            16        3.0       1977.0       43108.0
#
#         bedrooms   baths   addition_a  garage_con   garage_sta   carport_st  \
# 31030       82.0     7.9      52917.0           N        674.0         82.0
#
# ...

# %%
data[data[' address'] == '4149 NOBEL DR']
# Out:
#       count  ProjectName  OfficePhoneNumber   email  website   parcelnumb  \
# 1674  11117          NaN     (858) 638-0105     NaN      NaN   3487500200
#
#                    owner        address      scity        szip   usecode  \
# 1674  LA JOLLA NOBEL L P  4149 NOBEL DR  SAN DIEGO  92122-1105    1200.0
#
#        ll_bldg_footprint_sqft   ll_bldg_count     parval  owner2  \
# 1674                  17024.0             3.0  4159547.0     NaN
#
#                                      mailadd                    careof  \
# 1674  9948 HIBERT ST #210 SAN DIEGO CA 92131  WILLMARK COMMUNITIES INC
#
#       ownerocc   unitqty   asr_landuse   asr_zone   year_effec   total_lvg_   \
# 1674       NaN      44.0            16        3.0       1977.0       27294.0
#
#        bedrooms   baths   addition_a  garage_con   garage_sta   carport_st  \
# 1674       82.0     7.9      52917.0           N        620.0         82.0
#
# ...
