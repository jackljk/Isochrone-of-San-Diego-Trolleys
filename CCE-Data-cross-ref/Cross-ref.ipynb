# %%
import pandas as pd

# %%
data = pd.read_csv('Appendix D_ OutreachCallsSourceData2.xlsx - OutreachCallsSourceData2.csv')
# Out:
# c:\Users\16195\anaconda3\envs\dsc80\lib\site-packages\IPython\core\interactiveshell.py:3378: DtypeWarning: Columns (1,2,4,34,35,36,37,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#    count                                        ProjectName  \
# 0   6366  9951 Dolores St Spring Valley; CA 91977 - Apar...
# 1  12411                                                NaN
# 2  12389                                                NaN
# 3  12338                                                NaN
# 4  10920                                                NaN
#
#    OfficePhoneNumber   email  \
# 0     (209) 764-0077     NaN
# 1     (442) 245-5178     NaN
# 2     (442) 245-5429     NaN
# 3     (442) 245-5429     NaN
# 4     (442) 248-8207     NaN
#
#                                              website   parcelnumb  \
# 0  https://www.apartments.com/9951-dolores-st-spr...   5012470100
# 1                                                NaN   1690111200
# 2                                                NaN   1614901300
# 3                                                NaN   1614901200
# 4                                                NaN   2291603000
#
# ...
